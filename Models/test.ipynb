# %%
import os
os.getcwd()
from PIL import Image
import numpy as np
import random

# %%
random_number = random.randint(1, 200000)
print(f'Crop #{random_number}')

crop = Image.open(f'../../Local Data Files/WMAP/Datasets/SkymapK1_9yr_res9/crop_{random_number}.png')
print(crop.size, type(crop))

img = np.asarray(crop.getdata())
print(img.shape, type(img), end='\n\n') # 3 dimensional for RGB
for i in img:
    print(i if not np.array_equal(i, np.array([255, 255, 255])) else '', end='') # just curious about the pixel values since i've only seen 255, 255, 255
# Out:
# Crop #195561
# (28, 28) <class 'PIL.PngImagePlugin.PngImageFile'>
# (784, 3) <class 'numpy.ndarray'>
#
# ...
